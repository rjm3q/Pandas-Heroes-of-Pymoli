# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib notebook
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
pdata = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
pdatadf = pd.read_csv(pdata)
pdatadf.head(30)
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Lisim78   20                   Male      108
# 1             1    Lisovynya38   40                   Male      143
# 2             2     Ithergue48   24                   Male       92
# 3             3  Chamassasya86   24                   Male      100
# 4             4      Iskosia90   23                   Male      131
# 5             5        Yalae81   22                   Male       81
# 6             6      Itheria73   36                   Male      169
# 7             7    Iskjaskst81   20                   Male      162
# 8             8      Undjask33   22                   Male       21
# 9             9    Chanosian48   35  Other / Non-Disclosed      136
# 10           10      Inguron55   23                   Male       95
# 11           11   Haisrisuir60   23                   Male      162
# 12           12   Saelaephos52   21                   Male      116
# 13           13    Assjaskan73   22                   Male        4
# 14           14    Saesrideu94   35                   Male      165
# 15           15      Lisassa64   21                 Female       98
# 16           16      Lisirra25   20                   Male       40
# 17           17      Zontibe81   21                   Male      161
# 18           18      Reunasu60   22                 Female       82
# 19           19      Chamalo71   30                   Male       89
# 20           20   Iathenudil29   20                   Male       57
# 21           21  Phiarithdeu40   20                   Male      168
# 22           22   Siarithria38   38  Other / Non-Disclosed       24
# 23           23       Eyrian71   40                   Male      151
# 24           24        Siala43   30                   Male      141
# 25           25      Lisirra87   29                   Male      178
# 26           26     Lirtossa84   11                   Male       71
# 27           27        Eusri44    7                   Male       96
# 28           28         Aela59   21                   Male      119
# 29           29        Tyida79   24                   Male       37
#
#                                        Item Name  Price
# 0      Extraction, Quickblade Of Trembling Hands   3.53
# 1                              Frenzied Scimitar   1.56
# 2                                   Final Critic   4.88
# 3                                    Blindscythe   3.27
# 4                                           Fury   1.44
# 5                                      Dreamkiss   3.61
# 6         Interrogator, Blood Blade of the Queen   2.18
# 7                                  Abyssal Shard   2.67
# 8                                      Souleater   1.10
# 9                   Ghastly Adamantite Protector   3.58
# 10                         Singed Onyx Warscythe   4.74
# 11                                 Abyssal Shard   2.67
# 12                       Renewed Skeletal Katana   4.18
# 13                            Bloodlord's Fetish   1.70
# 14                   Bone Crushing Silver Skewer   4.86
# 15                   Deadline, Voice Of Subtlety   2.89
# 16                                 Second Chance   2.52
# 17                                        Devine   1.76
# 18                                       Nirvana   4.90
# 19             Blazefury, Protector of Delusions   4.64
# 20               Despair, Favor of Due Diligence   4.60
# 21           Sun Strike, Jaws of Twisted Visions   1.48
# 22                                 Warped Fetish   3.81
# 23                                     Severance   3.40
# 24                                    Persuasion   3.19
# 25  Oathbreaker, Last Hope of the Breaking Storm   4.23
# 26                                        Demise   1.61
# 27                   Blood-Forged Skeletal Spine   3.09
# 28     Stormbringer, Dark Blade of Ending Misery   4.32
# 29           Shadow Strike, Glory of Ending Hope   3.16

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
count = len(pdatadf["SN"].value_counts())
countdf = pd.DataFrame({"# Total Players": count}, index=[0])
countdf
# Out:
#    # Total Players
# 0              576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Count unique items
uitems = len(pdatadf['SN'].value_counts())

#average purchase price
avgprice = pdatadf['Price'].mean()

#number of pruchases
prch = pdatadf['Item Name'].count()

#revenue total
rev = pdatadf['Price'].sum()

padf = pd.DataFrame({'# of Unique Items': [uitems], 'AVG Price': [avgprice],
                    'Total Purchases': [prch], 'Total Revenue': [rev]})
padf
# Out:
#    # of Unique Items  AVG Price  Total Purchases  Total Revenue
# 0                576   3.050987              780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gdf = pdatadf.groupby(['Gender'])
ngdf = gdf.nunique()

#tot gender
tgen = ngdf['SN'].sum()
gcount = ngdf['SN'].unique()

#percent
pgen = ngdf['SN']/tgen

#Framed Data
demodf = pd.DataFrame({'% of Players': pgen, '#': gcount})
demodf['% of Players'] = demodf['% of Players'].map("{:,.2%}".format)
demodf
# Out:
#                       % of Players    #
# Gender
# Female                      14.06%   81
# Male                        84.03%  484
# Other / Non-Disclosed        1.91%   11

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
pcount = ngdf['Gender'].value_counts()
# avg and tot purchase price
avgprice = gdf['Price'].mean()
totprice = gdf['Price'].sum()
# fixed totals
fprice = totprice / gcount

#New Frame
Genanalysis = pd.DataFrame({'Average Price': avgprice, 'Purchase Price' : totprice,
                           'Fixed Prices Total': fprice})
#Genanalysis = ['Fixed Prices Total'] = Genanalysis['Fixed Prices Total'].map("${:,.2f}".format)
Genanalysis
# Out:
#                        Average Price  Purchase Price  Fixed Prices Total
# Gender
# Female                      3.203009          361.94            4.468395
# Male                        3.017853         1967.64            4.065372
# Other / Non-Disclosed       3.346000           50.19            4.562727

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
newdf = pdatadf.drop_duplicates('SN')

bins= [0,9,14,19,24,29,34,39,100]
group= ["Under 10", "10-14", "14-15", "15-19", "20-24", "30-34", "35-39", "Over 40"]

newdf["Age Brackets"]=pd.cut(newdf["Age"], bins, labels=group)
agedf = newdf.groupby(["Age Brackets"])

totalage = ngdf['Age'].sum()

#count of purchases
page= newdf["Age Brackets"].value_counts()

#% of users
perage = page/count

agedemo = pd.DataFrame({'Total Count of Purchases': page, "% of Players": perage})
agedemo['% of Players']=agedemo['% of Players'].map("{:,.2%}".format)

agedemo
# Out:
# C:\Users\rober\Anaconda3\envs\PythonData37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           Total Count of Purchases % of Players
# 15-19                          258       44.79%
# 14-15                          107       18.58%
# 20-24                           77       13.37%
# 30-34                           52        9.03%
# 35-39                           31        5.38%
# 10-14                           22        3.82%
# Under 10                        17        2.95%
# Over 40                         12        2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
avgpage = agedf['Price'].mean()

aprice = agedf['Price'].sum()

#fixed totals
fixedage= aprice/page

#age dataframe for analysis
aaly = pd.DataFrame({"# Purchase": page, "AVG Price": avgpage,
                     "Total Value": aprice, "Fixed Totals": fixedage})
aaly = pd.concat([aaly.loc[["Under 10"],:], aaly.drop("Under 10", axis=0)], axis=0)
aaly
# Out:
#           # Purchase  AVG Price  Total Value  Fixed Totals
# Under 10          17   3.390000        57.63      3.390000
# 10-14             22   3.074545        67.64      3.074545
# 14-15            107   3.101682       331.88      3.101682
# 15-19            258   3.063527       790.39      3.063527
# 20-24             77   2.908182       223.93      2.908182
# 30-34             52   2.921538       151.92      2.921538
# 35-39             31   3.510000       108.81      3.510000
# Over 40           12   3.037500        36.45      3.037500

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
spengrp = pdatadf.groupby(['SN'])

#total per user spent
totsn = spengrp.sum()["Price"]

#per user avg
avgsn = spengrp.mean()["Price"]

#count of purchases
cntsn = spengrp.count()["Price"]

#new df
spendf = pd.DataFrame({"Total Amount Spent": totsn, 
                       "Avg Purchase in $": avgsn,
                      "# of Purchases": cntsn})
sortdf = spendf.sort_values("Total Amount Spent", ascending=False)
sortdf["Avg Purchase in $"]=sortdf["Avg Purchase in $"].map("${:,.2f}".format)
sortdf["Total Amount Spent"]=sortdf["Total Amount Spent"].map("${:,.2f}".format)
sortdf
# Out:
#               Total Amount Spent Avg Purchase in $  # of Purchases
# SN
# Lisosia93                 $18.96             $3.79               5
# Idastidru52               $15.45             $3.86               4
# Chamjask73                $13.83             $4.61               3
# Iral74                    $13.62             $3.40               4
# Iskadarya95               $13.10             $4.37               3
# Ilarin91                  $12.70             $4.23               3
# Ialallo29                 $11.84             $3.95               3
# Tyidaim51                 $11.83             $3.94               3
# Lassilsala30              $11.51             $3.84               3
# Chadolyla44               $11.46             $3.82               3
# Iri67                     $11.37             $3.79               3
# Inguron55                 $11.11             $3.70               3
# Siallylis44               $10.37             $3.46               3
# Saistyphos30              $10.33             $3.44               3
# Phyali88                  $10.30             $3.43               3
# Strithenu87               $10.18             $3.39               3
# Lisim78                   $10.02             $3.34               3
# Haillyrgue51               $9.50             $3.17               3
# Phistym51                  $9.50             $4.75               2
# Lamil79                    $9.29             $4.64               2
# Aina42                     $9.22             $3.07               3
# Saesrideu94                $9.18             $4.59               2
# Arin32                     $9.09             $4.54               2
# Rarallo90                  $9.05             $3.02               3
# Baelollodeu94              $9.03             $4.51               2
# Aelin32                    $8.98             $2.99               3
# Lisopela58                 $8.86             $2.95               3
# Saedaiphos46               $8.83             $2.94               3
# Reunasu60                  $8.82             $4.41               2
# Chanastnya43               $8.82             $2.94               3
# ...                          ...               ...             ...
# Lirtim36                   $1.33             $1.33               1
# Shidai42                   $1.33             $1.33               1
# Philodil43                 $1.29             $1.29               1
# Eyista89                   $1.29             $1.29               1
# Mindilsa60                 $1.28             $1.28               1
# Tyarithn67                 $1.14             $1.14               1
# Aisur51                    $1.14             $1.14               1
# Ilista82                   $1.14             $1.14               1
# Jiskimsda56                $1.14             $1.14               1
# Aillyriadru65              $1.10             $1.10               1
# Eryon48                    $1.10             $1.10               1
# Iduelis31                  $1.10             $1.10               1
# Yasur85                    $1.10             $1.10               1
# Undjask33                  $1.10             $1.10               1
# Lirtassa52                 $1.09             $1.09               1
# Aelidru27                  $1.09             $1.09               1
# Yalaeria91                 $1.06             $1.06               1
# Aesurstilis64              $1.03             $1.03               1
# Saida58                    $1.03             $1.03               1
# Euthe35                    $1.03             $1.03               1
# Hala31                     $1.02             $1.02               1
# Qilalista41                $1.02             $1.02               1
# Frichjaskan98              $1.02             $1.02               1
# Isurria36                  $1.02             $1.02               1
# Eudanu84                   $1.02             $1.02               1
# Ililsasya43                $1.02             $1.02               1
# Irilis75                   $1.02             $1.02               1
# Aidai61                    $1.01             $1.01               1
# Chanirra79                 $1.01             $1.01               1
# Alo38                      $1.00             $1.00               1
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items= pdatadf.set_index(["Item ID", "Item Name"])
items= items.groupby(level=["Item ID", "Item Name"])

#find, count, avg items
countid= items.count()["Price"]
totid= items.sum()["Price"]
avgid= items.mean()["Price"]

itemdf= pd.DataFrame({"Item Count": countid, "Total Price": totid,
                     "Avg Purchase Price": avgid})
#sort by Item Count
srtitemdf= itemdf.sort_values("Item Count", ascending=False)

#add $ to the prices columns
srtitemdf["Total Price"]= srtitemdf["Total Price"].map("${:,.2f}".format)
srtitemdf["Avg Purchase Price"]= srtitemdf["Avg Purchase Price"].map("${:,.2f}".format)

srtitemdf
# Out:
#                                                       Item Count Total Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm          12      $50.76
# 145     Fiery Glass Crusader                                   9      $41.22
# 108     Extraction, Quickblade Of Trembling Hands              9      $31.77
# 82      Nirvana                                                9      $44.10
# 19      Pursuit, Cudgel of Necromancy                          8       $8.16
# 103     Singed Scalpel                                         8      $34.80
# 75      Brutality Ivory Warmace                                8      $19.36
# 72      Winter's Bite                                          8      $30.16
# 60      Wolf                                                   8      $28.32
# 59      Lightning, Etcher of the King                          8      $33.84
# 37      Shadow Strike, Glory of Ending Hope                    8      $25.28
# 34      Retribution Axe                                        8      $17.76
# 92      Final Critic                                           8      $39.04
# 53      Vengeance Cleaver                                      7      $14.35
# 110     Suspension                                             7      $10.08
# 7       Thorn, Satchel of Dark Souls                           7       $9.31
# 71      Demise                                                 7      $11.27
# 117     Heartstriker, Legacy of the Light                      7      $12.53
# 159     Oathbreaker, Spellblade of Trials                      7      $21.56
# 85      Malificent Bag                                         7      $12.25
# 164     Exiled Doomblade                                       7      $11.41
# 141     Persuasion                                             7      $22.33
# 78      Glimmer, Ender of the Moon                             7      $30.80
# 102     Avenger                                                6      $20.64
# 129     Fate, Vengeance of Eternal Justice                     6       $9.24
# 93      Apocalyptic Battlescythe                               6      $11.82
# 54      Eternal Cleaver                                        6      $15.00
# 3       Phantomlight                                           6      $14.94
# 2       Verdict                                                6      $14.88
# 40      Second Chance                                          6      $15.12
# ...                                                          ...         ...
# 81      Dreamkiss                                              2       $7.22
# 6       Rusty Skull                                            2       $7.40
# 18      Torchlight, Bond of Storms                             2       $9.30
# 26      Unholy Wand                                            2       $2.24
# 28      Flux, Destroyer of Due Diligence                       2       $2.12
# 30      Stormcaller                                            2       $4.42
# 158     Darkheart, Butcher of the Champion                     2       $4.90
# 69      Frenzy, Defender of the Harvest                        2       $3.96
# 132     Persuasion                                             2       $6.66
# 63      Stormfury Mace                                         2       $9.98
# 56      Foul Titanium Battle Axe                               2       $5.84
# 127     Heartseeker, Reaver of Souls                           2       $7.84
# 48      Rage, Legacy of the Lone Victor                        2       $4.96
# 125     Whistling Mithril Warblade                             2       $2.00
# 43      Foul Edge                                              2       $7.08
# 115     Spectral Diamond Doomblade                             2       $4.08
# 33      Curved Axe                                             2       $2.32
# 31      Trickster                                              2       $3.10
# 118     Ghost Reaver, Longsword of Magic                       1       $2.17
# 47      Alpha, Reach of Ending Hope                            1       $3.58
# 42      The Decapitator                                        1       $1.75
# 27      Riddle, Tribute of Ended Dreams                        1       $3.30
# 126     Exiled Mithril Longsword                               1       $2.00
# 51      Endbringer                                             1       $4.66
# 90      Betrayer                                               1       $2.94
# 104     Gladiator's Glaive                                     1       $1.93
# 23      Crucifer                                               1       $1.99
# 180     Stormcaller                                            1       $3.36
# 91      Celeste                                                1       $4.17
# 134     Undead Crusader                                        1       $4.50
#
#                                                      Avg Purchase Price
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              $4.23
# 145     Fiery Glass Crusader                                      $4.58
# 108     Extraction, Quickblade Of Trembling Hands                 $3.53
# 82      Nirvana                                                   $4.90
# 19      Pursuit, Cudgel of Necromancy                             $1.02
# 103     Singed Scalpel                                            $4.35
# 75      Brutality Ivory Warmace                                   $2.42
# 72      Winter's Bite                                             $3.77
# 60      Wolf                                                      $3.54
# 59      Lightning, Etcher of the King                             $4.23
# 37      Shadow Strike, Glory of Ending Hope                       $3.16
# 34      Retribution Axe                                           $2.22
# 92      Final Critic                                              $4.88
# 53      Vengeance Cleaver                                         $2.05
# 110     Suspension                                                $1.44
# 7       Thorn, Satchel of Dark Souls                              $1.33
# 71      Demise                                                    $1.61
# 117     Heartstriker, Legacy of the Light                         $1.79
# 159     Oathbreaker, Spellblade of Trials                         $3.08
# 85      Malificent Bag                                            $1.75
# 164     Exiled Doomblade                                          $1.63
# 141     Persuasion                                                $3.19
# 78      Glimmer, Ender of the Moon                                $4.40
# 102     Avenger                                                   $3.44
# 129     Fate, Vengeance of Eternal Justice                        $1.54
# 93      Apocalyptic Battlescythe                                  $1.97
# 54      Eternal Cleaver                                           $2.50
# 3       Phantomlight                                              $2.49
# 2       Verdict                                                   $2.48
# 40      Second Chance                                             $2.52
# ...                                                                 ...
# 81      Dreamkiss                                                 $3.61
# 6       Rusty Skull                                               $3.70
# 18      Torchlight, Bond of Storms                                $4.65
# 26      Unholy Wand                                               $1.12
# 28      Flux, Destroyer of Due Diligence                          $1.06
# 30      Stormcaller                                               $2.21
# 158     Darkheart, Butcher of the Champion                        $2.45
# 69      Frenzy, Defender of the Harvest                           $1.98
# 132     Persuasion                                                $3.33
# 63      Stormfury Mace                                            $4.99
# 56      Foul Titanium Battle Axe                                  $2.92
# 127     Heartseeker, Reaver of Souls                              $3.92
# 48      Rage, Legacy of the Lone Victor                           $2.48
# 125     Whistling Mithril Warblade                                $1.00
# 43      Foul Edge                                                 $3.54
# 115     Spectral Diamond Doomblade                                $2.04
# 33      Curved Axe                                                $1.16
# 31      Trickster                                                 $1.55
# 118     Ghost Reaver, Longsword of Magic                          $2.17
# 47      Alpha, Reach of Ending Hope                               $3.58
# 42      The Decapitator                                           $1.75
# 27      Riddle, Tribute of Ended Dreams                           $3.30
# 126     Exiled Mithril Longsword                                  $2.00
# 51      Endbringer                                                $4.66
# 90      Betrayer                                                  $2.94
# 104     Gladiator's Glaive                                        $1.93
# 23      Crucifer                                                  $1.99
# 180     Stormcaller                                               $3.36
# 91      Celeste                                                   $4.17
# 134     Undead Crusader                                           $4.50
#
# [183 rows x 3 columns]

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
srtitemdf= itemdf.sort_values("Total Price", ascending=False)

#add $ to the prices columns
srtitemdf["Total Price"]= srtitemdf["Total Price"].map("${:,.2f}".format)
srtitemdf["Avg Purchase Price"]= srtitemdf["Avg Purchase Price"].map("${:,.2f}".format)

srtitemdf
# Out:
#                                                       Item Count Total Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm          12      $50.76
# 82      Nirvana                                                9      $44.10
# 145     Fiery Glass Crusader                                   9      $41.22
# 92      Final Critic                                           8      $39.04
# 103     Singed Scalpel                                         8      $34.80
# 59      Lightning, Etcher of the King                          8      $33.84
# 108     Extraction, Quickblade Of Trembling Hands              9      $31.77
# 78      Glimmer, Ender of the Moon                             7      $30.80
# 72      Winter's Bite                                          8      $30.16
# 60      Wolf                                                   8      $28.32
# 179     Wolf, Promise of the Moonwalker                        6      $26.88
# 160     Azurewrath                                             6      $26.40
# 25      Hero Cane                                              6      $26.10
# 37      Shadow Strike, Glory of Ending Hope                    8      $25.28
# 139     Mercy, Katana of Dismay                                5      $24.70
# 128     Blazeguard, Reach of Eternity                          5      $24.55
# 138     Peacekeeper, Wit of Dark Magic                         5      $23.70
# 141     Persuasion                                             7      $22.33
# 87      Deluge, Edge of the West                               5      $22.15
# 159     Oathbreaker, Spellblade of Trials                      7      $21.56
# 136     Ghastly Adamantite Protector                           6      $21.48
# 65      Conqueror Adamantite Mace                              5      $21.20
# 101     Final Critic                                           5      $20.95
# 102     Avenger                                                6      $20.64
# 133     Faith's Scimitar                                       5      $20.45
# 39      Betrayal, Whisper of Grieving Widows                   5      $19.70
# 111     Misery's End                                           4      $19.56
# 165     Bone Crushing Silver Skewer                            4      $19.44
# 75      Brutality Ivory Warmace                                8      $19.36
# 52      Hatred                                                 4      $19.36
# ...                                                          ...         ...
# 124     Venom Claymore                                         4       $5.16
# 0       Splinter                                               4       $5.12
# 155     War-Forged Gold Deflector                              5       $5.05
# 48      Rage, Legacy of the Lone Victor                        2       $4.96
# 158     Darkheart, Butcher of the Champion                     2       $4.90
# 51      Endbringer                                             1       $4.66
# 134     Undead Crusader                                        1       $4.50
# 30      Stormcaller                                            2       $4.42
# 135     Warped Diamond Crusader                                3       $4.20
# 91      Celeste                                                1       $4.17
# 177     Winterthorn, Defender of Shifting Worlds               2       $4.16
# 70      Hope's End                                             4       $4.12
# 115     Spectral Diamond Doomblade                             2       $4.08
# 69      Frenzy, Defender of the Harvest                        2       $3.96
# 47      Alpha, Reach of Ending Hope                            1       $3.58
# 180     Stormcaller                                            1       $3.36
# 27      Riddle, Tribute of Ended Dreams                        1       $3.30
# 183     Dragon's Greatsword                                    3       $3.27
# 31      Trickster                                              2       $3.10
# 168     Sun Strike, Jaws of Twisted Visions                    2       $2.96
# 90      Betrayer                                               1       $2.94
# 33      Curved Axe                                             2       $2.32
# 26      Unholy Wand                                            2       $2.24
# 118     Ghost Reaver, Longsword of Magic                       1       $2.17
# 28      Flux, Destroyer of Due Diligence                       2       $2.12
# 125     Whistling Mithril Warblade                             2       $2.00
# 126     Exiled Mithril Longsword                               1       $2.00
# 23      Crucifer                                               1       $1.99
# 104     Gladiator's Glaive                                     1       $1.93
# 42      The Decapitator                                        1       $1.75
#
#                                                      Avg Purchase Price
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              $4.23
# 82      Nirvana                                                   $4.90
# 145     Fiery Glass Crusader                                      $4.58
# 92      Final Critic                                              $4.88
# 103     Singed Scalpel                                            $4.35
# 59      Lightning, Etcher of the King                             $4.23
# 108     Extraction, Quickblade Of Trembling Hands                 $3.53
# 78      Glimmer, Ender of the Moon                                $4.40
# 72      Winter's Bite                                             $3.77
# 60      Wolf                                                      $3.54
# 179     Wolf, Promise of the Moonwalker                           $4.48
# 160     Azurewrath                                                $4.40
# 25      Hero Cane                                                 $4.35
# 37      Shadow Strike, Glory of Ending Hope                       $3.16
# 139     Mercy, Katana of Dismay                                   $4.94
# 128     Blazeguard, Reach of Eternity                             $4.91
# 138     Peacekeeper, Wit of Dark Magic                            $4.74
# 141     Persuasion                                                $3.19
# 87      Deluge, Edge of the West                                  $4.43
# 159     Oathbreaker, Spellblade of Trials                         $3.08
# 136     Ghastly Adamantite Protector                              $3.58
# 65      Conqueror Adamantite Mace                                 $4.24
# 101     Final Critic                                              $4.19
# 102     Avenger                                                   $3.44
# 133     Faith's Scimitar                                          $4.09
# 39      Betrayal, Whisper of Grieving Widows                      $3.94
# 111     Misery's End                                              $4.89
# 165     Bone Crushing Silver Skewer                               $4.86
# 75      Brutality Ivory Warmace                                   $2.42
# 52      Hatred                                                    $4.84
# ...                                                                 ...
# 124     Venom Claymore                                            $1.29
# 0       Splinter                                                  $1.28
# 155     War-Forged Gold Deflector                                 $1.01
# 48      Rage, Legacy of the Lone Victor                           $2.48
# 158     Darkheart, Butcher of the Champion                        $2.45
# 51      Endbringer                                                $4.66
# 134     Undead Crusader                                           $4.50
# 30      Stormcaller                                               $2.21
# 135     Warped Diamond Crusader                                   $1.40
# 91      Celeste                                                   $4.17
# 177     Winterthorn, Defender of Shifting Worlds                  $2.08
# 70      Hope's End                                                $1.03
# 115     Spectral Diamond Doomblade                                $2.04
# 69      Frenzy, Defender of the Harvest                           $1.98
# 47      Alpha, Reach of Ending Hope                               $3.58
# 180     Stormcaller                                               $3.36
# 27      Riddle, Tribute of Ended Dreams                           $3.30
# 183     Dragon's Greatsword                                       $1.09
# 31      Trickster                                                 $1.55
# 168     Sun Strike, Jaws of Twisted Visions                       $1.48
# 90      Betrayer                                                  $2.94
# 33      Curved Axe                                                $1.16
# 26      Unholy Wand                                               $1.12
# 118     Ghost Reaver, Longsword of Magic                          $2.17
# 28      Flux, Destroyer of Due Diligence                          $1.06
# 125     Whistling Mithril Warblade                                $1.00
# 126     Exiled Mithril Longsword                                  $2.00
# 23      Crucifer                                                  $1.99
# 104     Gladiator's Glaive                                        $1.93
# 42      The Decapitator                                           $1.75
#
# [183 rows x 3 columns]
